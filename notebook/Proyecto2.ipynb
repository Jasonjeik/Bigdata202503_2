# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://jasonebm16_db_user:JK0jknwzzkJdRaDt@bdproyecto2.u5gbblq.mongodb.net/?appName=BDProyecto2"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# c:\Users\Flia Barrios Atencio\OneDrive - Acesco\0. Personales\2. Profesional\20240416 - Maestria en Analítica de Datos\20251024 Big Data\Proyecto 1\Function\.venv\Lib\site-packages\pymongo\pyopenssl_context.py:352: CryptographyDeprecationWarning: Parsed a serial number which wasn't positive (i.e., it was negative or zero), which is disallowed by RFC 5280. Loading this certificate will cause an exception in a future release of cryptography.
#   _crypto.X509.from_cryptography(x509.load_der_x509_certificate(cert))
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# CELDA PARA SUBIR EL DATASET IMDB A MONGODB ATLAS (EJECUTAR UNA SOLA VEZ)
import pandas as pd
from pymongo import MongoClient
from pymongo.server_api import ServerApi

# 1. CARGAR EL CSV ORIGINAL
df = pd.read_csv("C:\\Users\\Flia Barrios Atencio\\OneDrive - Acesco\\0. Personales\\2. Profesional\\20240416 - Maestria en Analítica de Datos\\20251024 Big Data\\Proyecto 2\\data\\archive\\IMDB Dataset.csv")

# 2. VERIFICAR NOMBRES DE COLUMNAS (para que veamos exactamente cómo viene)
print("Columnas originales:", df.columns.tolist())
print("Primeras filas:\n", df.head(2))

# 3. LIMPIAR Y RENOMBRAR (una sola vez, sin duplicar)
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# Si las columnas se llaman 'review' y 'sentiment' → renombrar
if 'review' in df.columns:
    df = df.rename(columns={'review': 'text', 'sentiment': 'label'})
elif 'text' in df.columns:
    df = df.rename(columns={'sentiment': 'label'})  # ya tiene 'text'

# Seleccionar solo las columnas necesarias
df = df[['text', 'label']].copy()

print(f"Dataset preparado: {len(df):,} reseñas")
print("Columnas finales:", df.columns.tolist())

# 4. CONECTAR Y SUBIR A MONGODB ATLAS
uri = "mongodb+srv://jasonebm16_db_user:JK0jknwzzkJdRaDt@bdproyecto2.u5gbblq.mongodb.net/?appName=BDProyecto2"
client = MongoClient(uri, server_api=ServerApi('1'))

db = client["imdb_dataset"]      # base de datos limpia
collection = db["reviews"]       # colección clara

# Limpiar colección si ya existe y subir todo
collection.delete_many({})
data_dict = df.to_dict("records")
collection.insert_many(data_dict)

print(f"\n¡SUBIDA COMPLETADA!")
print(f"→ Base de datos: imdb_dataset")
print(f"→ Colección:     reviews")
print(f"→ Documentos:    {collection.count_documents({}):,}")
print(f"→ Ejemplo de documento:")
print(collection.find_one())

client.close()
# Out:
# Columnas originales: ['review', 'sentiment']
# Primeras filas:
#                                                review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# Dataset preparado: 50,000 reseñas
# Columnas finales: ['text', 'label']
# c:\Users\Flia Barrios Atencio\OneDrive - Acesco\0. Personales\2. Profesional\20240416 - Maestria en Analítica de Datos\20251024 Big Data\Proyecto 1\Function\.venv\Lib\site-packages\pymongo\pyopenssl_context.py:352: CryptographyDeprecationWarning: Parsed a serial number which wasn't positive (i.e., it was negative or zero), which is disallowed by RFC 5280. Loading this certificate will cause an exception in a future release of cryptography.
#   _crypto.X509.from_cryptography(x509.load_der_x509_certificate(cert))
# ¡SUBIDA COMPLETADA!
# → Base de datos: imdb_dataset
# → Colección:     reviews
# → Documentos:    50,000
# → Ejemplo de documento:
# ...

# %%
# CELDA ÚNICA: SUBIR IMDB Dataset.csv A MONGODB ATLAS (una sola vez)
import pandas as pd
from pymongo import MongoClient
from pymongo.server_api import ServerApi

# 1. Cargar el CSV original (el mismo que usabas antes)

# 2. Convertir sentiment a formato limpio
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# 3. Renombrar columnas para que coincidan con lo que espera el resto del código
df = df.rename(columns={'review': 'text', 'sentiment': 'label'})

# Cambia 'review' por el nombre real de la columna si es diferente

# Si la columna se llama 'review':
df = df[['review', 'sentiment']].rename(columns={'review': 'text', 'sentiment': 'label'})

# 4. Conectar a tu cluster
uri = "mongodb+srv://jasonebm16_db_user:JK0jknwzzkJdRaDt@bdproyecto2.u5gbblq.mongodb.net/?appName=BDProyecto2"
client = MongoClient(uri, server_api=ServerApi('1'))
db = client["imdb_dataset"]           # ← BASE DE DATOS NUEVA Y LIMPIA
collection = db["reviews"]            # ← COLECCIÓN CLARA

# 5. Borrar si ya existe (opcional) y subir todo
collection.delete_many({})  # limpia por si ya existe
data = df.to_dict("records")
collection.insert_many(data)

print(f"Dataset IMDB subido correctamente!")
print(f"Base de datos: imdb_dataset")
print(f"Colección:      reviews")
print(f"Documentos:     {collection.count_documents({}):,}")

client.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 18
#      13 df = df.rename(columns={'review': 'text', 'sentiment': 'label'})
#      15 # Cambia 'review' por el nombre real de la columna si es diferente
#      16
#      17 # Si la columna se llama 'review':
# ---> 18 df = df[['review', 'sentiment']].rename(columns={'review': 'text', 'sentiment': 'label'})
#      20 # 4. Conectar a tu cluster
#      21 uri = "mongodb+srv://jasonebm16_db_user:JK0jknwzzkJdRaDt@bdproyecto2.u5gbblq.mongodb.net/?appName=BDProyecto2"
#
# File c:\Users\Flia Barrios Atencio\OneDrive - Acesco\0. Personales\2. Profesional\20240416 - Maestria en Analítica de Datos\20251024 Big Data\Proyecto 1\Function\.venv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# ...
